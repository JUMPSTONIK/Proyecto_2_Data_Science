# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os



from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout
from keras.preprocessing.image import ImageDataGenerator
from tkinter import filedialog
import tensorflow as tf

# %%
import plotly.express as px  # (version 4.7.0)
import plotly.graph_objects as go

import dash  # (version 1.12.0) pip install dash
from dash.dependencies import Input, Output, State
import dash_core_components as dcc
import dash_html_components as html

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
train_df = pd.read_csv("boneage-training-dataset.csv")
print(train_df.shape)
# Out:
# (12611, 3)

# %%
train = train_df.head(10000)
test = train_df.tail(2600)

# %%
# quadratic approach
quadratic = True
image_size = 128

# some kind of ratio if not quadratic approach
img_rows = image_size if quadratic else 144 
img_cols = image_size if quadratic else 114

load_15_age_model = Sequential()
load_15_age_model.add(Conv2D(16, kernel_size=(7,7), strides=(2,2), activation='relu', input_shape=(img_rows, img_cols, 3)))
load_15_age_model.add(Dropout(0.25))

# Convulotional Layers
load_15_age_model.add(Conv2D(32, kernel_size=(5,5), strides=(2,2), activation='relu'))
load_15_age_model.add(Dropout(0.25))
load_15_age_model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
#bone_age_model.add(Dropout(0.25))
load_15_age_model.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
load_15_age_model.add(Dropout(0.25))

# Flattening
load_15_age_model.add(Flatten())

# Dense Layer
load_15_age_model.add(Dense(256, activation='relu'))
#bone_age_model.add(Dropout(0.25))
load_15_age_model.add(Dense(1, activation="linear"))

load_15_age_model.compile(loss='mean_squared_error', optimizer='adam', metrics='accuracy')

# %%
load_15_age_model.load_weights('seqModelo_weights_lineal_15.h5')

# %%
res=[]
for i in range(12705,15611):
    try:
        filepath = ("./boneage-training-dataset/boneage-training-dataset/"+str(i)+".png")
        print(filepath)
        image = tf.keras.preprocessing.image.load_img(filepath, target_size=(img_rows,img_cols))
        input_arr = keras.preprocessing.image.img_to_array(image)
        input_arr = np.array([input_arr])  # Convert single image to a batch.
        input_arr=input_arr/256
        predictions = load_15_age_model.predict(input_arr,  verbose = True)
        res.append(predictions[0][0])
        print(i)
    except:
        pass
print(res)
# Out:
# ./boneage-training-dataset/boneage-training-dataset/12705.png
# 1/1 [==============================] - 0s 106ms/step
# 12705
# ./boneage-training-dataset/boneage-training-dataset/12706.png
# 1/1 [==============================] - 0s 999us/step
# 12706
# ./boneage-training-dataset/boneage-training-dataset/12707.png
# 1/1 [==============================] - 0s 995us/step
# 12707
# ./boneage-training-dataset/boneage-training-dataset/12708.png
# ./boneage-training-dataset/boneage-training-dataset/12709.png
# 1/1 [==============================] - 0s 997us/step
# 12709
# ./boneage-training-dataset/boneage-training-dataset/12710.png
# 1/1 [==============================] - 0s 987us/step
# 12710
# ./boneage-training-dataset/boneage-training-dataset/12711.png
# 1/1 [==============================] - 0s 998us/step
# 12711
# ./boneage-training-dataset/boneage-training-dataset/12712.png
# 1/1 [==============================] - 0s 1ms/step
# 12712
# ./boneage-training-dataset/boneage-training-dataset/12713.png
# 1/1 [==============================] - 0s 981us/step
# 12713
# ./boneage-training-dataset/boneage-training-dataset/12714.png
# 1/1 [==============================] - 0s 870us/step
# 1/1 [==============================] - 0s 1ms/step
# 12743
# ./boneage-training-dataset/boneage-training-dataset/12744.png
# 1/1 [==============================] - 0s 1ms/step
# 12744
# ./boneage-training-dataset/boneage-training-dataset/12745.png
# 1/1 [==============================] - 0s 997us/step
# 12745
# ./boneage-training-dataset/boneage-training-dataset/12746.png
# 1/1 [==============================] - 0s 0s/step
# 12746
# ./boneage-training-dataset/boneage-training-dataset/12747.png
# 1/1 [==============================] - 0s 2ms/step
# 12747
# ./boneage-training-dataset/boneage-training-dataset/12748.png
# ./boneage-training-dataset/boneage-training-dataset/12749.png
# 1/1 [==============================] - 0s 1ms/step
# 12749
# ./boneage-training-dataset/boneage-training-dataset/12750.png
# 1/1 [==============================] - 0s 1ms/step
# 12750
# ./boneage-training-dataset/boneage-training-dataset/12751.png
# 1/1 [==============================] - 0s 998us/step
# 12751
# ./boneage-training-dataset/boneage-training-dataset/12752.png
# 1/1 [==============================] - 0s 0s/step
# 12752
# ./boneage-training-dataset/boneage-training-dataset/12753.png
# 1/1 [==============================] - 0s 988us/step
# 12753
# ./boneage-training-dataset/boneage-training-dataset/12754.png
# 1/1 [==============================] - 0s 1ms/step
# 12754
# ./boneage-training-dataset/boneage-training-dataset/12755.png
# 1/1 [==============================] - 0s 1ms/step
# 12755
# ./boneage-training-dataset/boneage-training-dataset/12756.png
# 1/1 [==============================] - 0s 0s/step
# 12756
# ./boneage-training-dataset/boneage-training-dataset/12757.png
# 1/1 [==============================] - 0s 1ms/step
# 12757
# ./boneage-training-dataset/boneage-training-dataset/12758.png
# 1/1 [==============================] - 0s 1ms/step
# 12758
# ./boneage-training-dataset/boneage-training-dataset/12759.png
# 1/1 [==============================] - 0s 2ms/step
# 12759
# ./boneage-training-dataset/boneage-training-dataset/12760.png
# 1/1 [==============================] - 0s 991us/step
# 12760
# ./boneage-training-dataset/boneage-training-dataset/12761.png
# 1/1 [==============================] - 0s 1ms/step
# 12761
# ./boneage-training-dataset/boneage-training-dataset/12762.png
# 1/1 [==============================] - 0s 964us/step
# 12762
# ./boneage-training-dataset/boneage-training-dataset/12763.png
# 1/1 [==============================] - 0s 998us/step
# 12763
# ./boneage-training-dataset/boneage-training-dataset/12764.png
# 1/1 [==============================] - 0s 1ms/step
# 12764
# ./boneage-training-dataset/boneage-training-dataset/12765.png
# 1/1 [==============================] - 0s 998us/step
# 12765
# ./boneage-training-dataset/boneage-training-dataset/12766.png
# 1/1 [==============================] - 0s 649us/step
# 12766
# ./boneage-training-dataset/boneage-training-dataset/12767.png
# 1/1 [==============================] - 0s 998us/step
# 12767
# ./boneage-training-dataset/boneage-training-dataset/12768.png
# 1/1 [==============================] - 0s 997us/step
# 12768
# ./boneage-training-dataset/boneage-training-dataset/12769.png
# 1/1 [==============================] - 0s 971us/step
# 12769
# ./boneage-training-dataset/boneage-training-dataset/12770.png
# 1/1 [==============================] - 0s 0s/step
# 12770
# ./boneage-training-dataset/boneage-training-dataset/12771.png
# 1/1 [==============================] - 0s 969us/step
# 12771
# 1/1 [==============================] - 0s 0s/step
# 12833
# ./boneage-training-dataset/boneage-training-dataset/12834.png
# 1/1 [==============================] - 0s 992us/step
# 12834
# ./boneage-training-dataset/boneage-training-dataset/12835.png
# 1/1 [==============================] - 0s 997us/step
# 12835
# ./boneage-training-dataset/boneage-training-dataset/12836.png
# 1/1 [==============================] - 0s 965us/step
# 12836
# ./boneage-training-dataset/boneage-training-dataset/12837.png
# 1/1 [==============================] - 0s 1ms/step
# 12837
# ./boneage-training-dataset/boneage-training-dataset/12838.png
# 1/1 [==============================] - 0s 1ms/step
# 12838
# ./boneage-training-dataset/boneage-training-dataset/12839.png
# ./boneage-training-dataset/boneage-training-dataset/12840.png
# 1/1 [==============================] - 0s 1ms/step
# 12840
# ./boneage-training-dataset/boneage-training-dataset/12841.png
# 1/1 [==============================] - 0s 0s/step
# 12841
# ./boneage-training-dataset/boneage-training-dataset/12842.png
# 1/1 [==============================] - 0s 1ms/step
# 12842
# ./boneage-training-dataset/boneage-training-dataset/12843.png
# ./boneage-training-dataset/boneage-training-dataset/12844.png
# ./boneage-training-dataset/boneage-training-dataset/12845.png
# 1/1 [==============================] - 0s 1ms/step
# 12845
# ./boneage-training-dataset/boneage-training-dataset/12846.png
# 1/1 [==============================] - 0s 2ms/step
# 12846
# ./boneage-training-dataset/boneage-training-dataset/12847.png
# 1/1 [==============================] - 0s 959us/step
# 12847
# ./boneage-training-dataset/boneage-training-dataset/12848.png
# 1/1 [==============================] - 0s 2ms/step
# 12848
# ./boneage-training-dataset/boneage-training-dataset/12849.png
# 1/1 [==============================] - 0s 998us/step
# 12849
# ./boneage-training-dataset/boneage-training-dataset/12850.png
# 1/1 [==============================] - 0s 972us/step
# 12850
# ./boneage-training-dataset/boneage-training-dataset/12851.png
# ./boneage-training-dataset/boneage-training-dataset/12852.png
# 1/1 [==============================] - 0s 968us/step
# 12852
# ./boneage-training-dataset/boneage-training-dataset/12853.png
# 1/1 [==============================] - 0s 0s/step
# 12853
# ./boneage-training-dataset/boneage-training-dataset/12854.png
# 1/1 [==============================] - 0s 1ms/step
# 12854
# ./boneage-training-dataset/boneage-training-dataset/12855.png
# 1/1 [==============================] - 0s 963us/step
# 12855
# ./boneage-training-dataset/boneage-training-dataset/12856.png
# 1/1 [==============================] - 0s 0s/step
# 12856
# ./boneage-training-dataset/boneage-training-dataset/12857.png
# 1/1 [==============================] - 0s 0s/step
# 12857
# ./boneage-training-dataset/boneage-training-dataset/12858.png
# ./boneage-training-dataset/boneage-training-dataset/12859.png
# 1/1 [==============================] - 0s 2ms/step
# 12859
# ./boneage-training-dataset/boneage-training-dataset/12860.png
# 1/1 [==============================] - 0s 1ms/step
# 12860
# ./boneage-training-dataset/boneage-training-dataset/12861.png
# 1/1 [==============================] - 0s 997us/step
# 12861
# ./boneage-training-dataset/boneage-training-dataset/12862.png
# 1/1 [==============================] - 0s 1ms/step
# 12862
# ./boneage-training-dataset/boneage-training-dataset/12863.png
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 0s/step
# 15508
# ./boneage-training-dataset/boneage-training-dataset/15509.png
# 1/1 [==============================] - 0s 998us/step
# 15509
# ./boneage-training-dataset/boneage-training-dataset/15510.png
# 1/1 [==============================] - 0s 1ms/step
# 15510
# ./boneage-training-dataset/boneage-training-dataset/15511.png
# 1/1 [==============================] - 0s 0s/step
# 15511
# ./boneage-training-dataset/boneage-training-dataset/15512.png
# 1/1 [==============================] - 0s 997us/step
# 15512
# ./boneage-training-dataset/boneage-training-dataset/15513.png
# 1/1 [==============================] - 0s 1ms/step
# 15513
# ./boneage-training-dataset/boneage-training-dataset/15514.png
# 1/1 [==============================] - 0s 0s/step
# 15514
# ./boneage-training-dataset/boneage-training-dataset/15515.png
# 1/1 [==============================] - 0s 1ms/step
# 15515
# ./boneage-training-dataset/boneage-training-dataset/15516.png
# 1/1 [==============================] - 0s 2ms/step
# 15516
# ./boneage-training-dataset/boneage-training-dataset/15517.png
# 1/1 [==============================] - 0s 996us/step
# 15517
# ./boneage-training-dataset/boneage-training-dataset/15518.png
# 1/1 [==============================] - 0s 1ms/step
# 15518
# ./boneage-training-dataset/boneage-training-dataset/15519.png
# 1/1 [==============================] - 0s 1ms/step
# 15519
# ./boneage-training-dataset/boneage-training-dataset/15520.png
# 1/1 [==============================] - 0s 965us/step
# 15520
# ./boneage-training-dataset/boneage-training-dataset/15521.png
# ./boneage-training-dataset/boneage-training-dataset/15522.png
# 1/1 [==============================] - 0s 997us/step
# 15522
# ./boneage-training-dataset/boneage-training-dataset/15523.png
# 1/1 [==============================] - 0s 998us/step
# 15523
# ./boneage-training-dataset/boneage-training-dataset/15524.png
# 1/1 [==============================] - 0s 2ms/step
# 15524
# ./boneage-training-dataset/boneage-training-dataset/15525.png
# 1/1 [==============================] - 0s 1ms/step
# 15525
# ./boneage-training-dataset/boneage-training-dataset/15526.png
# 1/1 [==============================] - 0s 965us/step
# 15526
# ./boneage-training-dataset/boneage-training-dataset/15527.png
# 1/1 [==============================] - 0s 1ms/step
# 15527
# ./boneage-training-dataset/boneage-training-dataset/15528.png
# 1/1 [==============================] - 0s 2ms/step
# 15528
# ./boneage-training-dataset/boneage-training-dataset/15529.png
# 1/1 [==============================] - 0s 9ms/step
# 15529
# ./boneage-training-dataset/boneage-training-dataset/15530.png
# 1/1 [==============================] - 0s 2ms/step
# 15530
# ./boneage-training-dataset/boneage-training-dataset/15531.png
# 1/1 [==============================] - 0s 2ms/step
# 15531
# ./boneage-training-dataset/boneage-training-dataset/15532.png
# 1/1 [==============================] - 0s 2ms/step
# 15532
# ./boneage-training-dataset/boneage-training-dataset/15533.png
# 1/1 [==============================] - 0s 962us/step
# 15533
# ./boneage-training-dataset/boneage-training-dataset/15534.png
# 1/1 [==============================] - 0s 984us/step
# 15534
# ./boneage-training-dataset/boneage-training-dataset/15535.png
# ./boneage-training-dataset/boneage-training-dataset/15536.png
# 1/1 [==============================] - 0s 964us/step
# 15536
# ./boneage-training-dataset/boneage-training-dataset/15537.png
# 1/1 [==============================] - 0s 1ms/step
# 15537
# ./boneage-training-dataset/boneage-training-dataset/15538.png
# 1/1 [==============================] - 0s 0s/step
# 15538
# ./boneage-training-dataset/boneage-training-dataset/15539.png
# ./boneage-training-dataset/boneage-training-dataset/15540.png
# 1/1 [==============================] - 0s 1ms/step
# 15540
# ./boneage-training-dataset/boneage-training-dataset/15541.png
# 1/1 [==============================] - 0s 0s/step
# 15541
# ./boneage-training-dataset/boneage-training-dataset/15542.png
# 1/1 [==============================] - 0s 0s/step
# 15542
# ./boneage-training-dataset/boneage-training-dataset/15543.png
# 1/1 [==============================] - 0s 1ms/step
# 15543
# ./boneage-training-dataset/boneage-training-dataset/15544.png
# 1/1 [==============================] - 0s 996us/step
# 15544
# ./boneage-training-dataset/boneage-training-dataset/15545.png
# 1/1 [==============================] - 0s 999us/step
# 15545
# ./boneage-training-dataset/boneage-training-dataset/15546.png
# 1/1 [==============================] - 0s 962us/step
# 15546
# ./boneage-training-dataset/boneage-training-dataset/15547.png
# ./boneage-training-dataset/boneage-training-dataset/15548.png
# 1/1 [==============================] - 0s 2ms/step
# 15548
# ./boneage-training-dataset/boneage-training-dataset/15549.png
# 1/1 [==============================] - 0s 5ms/step
# 15549
# ./boneage-training-dataset/boneage-training-dataset/15550.png
# 1/1 [==============================] - 0s 2ms/step
# 15550
# ./boneage-training-dataset/boneage-training-dataset/15551.png
# ./boneage-training-dataset/boneage-training-dataset/15552.png
# 1/1 [==============================] - 0s 1ms/step
# 15552
# ./boneage-training-dataset/boneage-training-dataset/15553.png
# 1/1 [==============================] - 0s 964us/step
# 15553
# ./boneage-training-dataset/boneage-training-dataset/15554.png
# ./boneage-training-dataset/boneage-training-dataset/15555.png
# 1/1 [==============================] - 0s 2ms/step
# 15555
# ./boneage-training-dataset/boneage-training-dataset/15556.png
# 1/1 [==============================] - 0s 962us/step
# 15556
# ./boneage-training-dataset/boneage-training-dataset/15557.png
# 1/1 [==============================] - 0s 1ms/step
# 15557
# ./boneage-training-dataset/boneage-training-dataset/15558.png
# 1/1 [==============================] - 0s 1ms/step
# 15558
# ./boneage-training-dataset/boneage-training-dataset/15559.png
# 1/1 [==============================] - 0s 965us/step
# 15559
# ./boneage-training-dataset/boneage-training-dataset/15560.png
# 1/1 [==============================] - 0s 0s/step
# 15560
# ./boneage-training-dataset/boneage-training-dataset/15561.png
# 1/1 [==============================] - 0s 0s/step
# 15561
# ./boneage-training-dataset/boneage-training-dataset/15562.png
# 1/1 [==============================] - 0s 971us/step
# 15562
# ./boneage-training-dataset/boneage-training-dataset/15563.png
# 1/1 [==============================] - 0s 998us/step
# 15563
# ./boneage-training-dataset/boneage-training-dataset/15564.png
# 1/1 [==============================] - 0s 1ms/step
# 15564
# ./boneage-training-dataset/boneage-training-dataset/15565.png
# 1/1 [==============================] - 0s 997us/step
# 15565
# ./boneage-training-dataset/boneage-training-dataset/15566.png
# ./boneage-training-dataset/boneage-training-dataset/15567.png
# 1/1 [==============================] - 0s 2ms/step
# 15567
# ./boneage-training-dataset/boneage-training-dataset/15568.png
# ./boneage-training-dataset/boneage-training-dataset/15569.png
# 1/1 [==============================] - 0s 997us/step
# 15569
# ./boneage-training-dataset/boneage-training-dataset/15570.png
# 1/1 [==============================] - 0s 998us/step
# 15570
# ./boneage-training-dataset/boneage-training-dataset/15571.png
# 1/1 [==============================] - 0s 979us/step
# 15571
# ./boneage-training-dataset/boneage-training-dataset/15572.png
# ./boneage-training-dataset/boneage-training-dataset/15573.png
# 1/1 [==============================] - 0s 1ms/step
# 15573
# ./boneage-training-dataset/boneage-training-dataset/15574.png
# 1/1 [==============================] - 0s 1ms/step
# 15574
# ./boneage-training-dataset/boneage-training-dataset/15575.png
# 1/1 [==============================] - 0s 963us/step
# 15575
# ./boneage-training-dataset/boneage-training-dataset/15576.png
# 1/1 [==============================] - 0s 0s/step
# 15576
# ./boneage-training-dataset/boneage-training-dataset/15577.png
# 1/1 [==============================] - 0s 996us/step
# 15577
# ./boneage-training-dataset/boneage-training-dataset/15578.png
# 1/1 [==============================] - 0s 1ms/step
# 15578
# ./boneage-training-dataset/boneage-training-dataset/15579.png
# 1/1 [==============================] - 0s 964us/step
# 15579
# ./boneage-training-dataset/boneage-training-dataset/15580.png
# 1/1 [==============================] - 0s 1ms/step
# 15580
# ./boneage-training-dataset/boneage-training-dataset/15581.png
# 1/1 [==============================] - 0s 1ms/step
# 15581
# ./boneage-training-dataset/boneage-training-dataset/15582.png
# 1/1 [==============================] - 0s 998us/step
# 15582
# ./boneage-training-dataset/boneage-training-dataset/15583.png
# 1/1 [==============================] - 0s 1ms/step
# 15583
# ./boneage-training-dataset/boneage-training-dataset/15584.png
# 1/1 [==============================] - 0s 2ms/step
# 15584
# ./boneage-training-dataset/boneage-training-dataset/15585.png
# 1/1 [==============================] - 0s 981us/step
# 15585
# ./boneage-training-dataset/boneage-training-dataset/15586.png
# 1/1 [==============================] - 0s 2ms/step
# 15586
# ./boneage-training-dataset/boneage-training-dataset/15587.png
# 1/1 [==============================] - 0s 967us/step
# 15587
# ./boneage-training-dataset/boneage-training-dataset/15588.png
# 1/1 [==============================] - 0s 1ms/step
# 15588
# ./boneage-training-dataset/boneage-training-dataset/15589.png
# 1/1 [==============================] - 0s 997us/step
# 15589
# ./boneage-training-dataset/boneage-training-dataset/15590.png
# ./boneage-training-dataset/boneage-training-dataset/15591.png
# 1/1 [==============================] - 0s 989us/step
# 15591
# ./boneage-training-dataset/boneage-training-dataset/15592.png
# ./boneage-training-dataset/boneage-training-dataset/15593.png
# 1/1 [==============================] - 0s 966us/step
# 15593
# ./boneage-training-dataset/boneage-training-dataset/15594.png
# 1/1 [==============================] - 0s 2ms/step
# 15594
# ./boneage-training-dataset/boneage-training-dataset/15595.png
# 1/1 [==============================] - 0s 985us/step
# 15595
# ./boneage-training-dataset/boneage-training-dataset/15596.png
# 1/1 [==============================] - 0s 1ms/step
# 15596
# ./boneage-training-dataset/boneage-training-dataset/15597.png
# 1/1 [==============================] - 0s 1ms/step
# 15597
# ./boneage-training-dataset/boneage-training-dataset/15598.png
# 1/1 [==============================] - 0s 963us/step
# 15598
# ./boneage-training-dataset/boneage-training-dataset/15599.png
# 1/1 [==============================] - 0s 998us/step
# 15599
# ./boneage-training-dataset/boneage-training-dataset/15600.png
# 1/1 [==============================] - 0s 0s/step
# 15600
# ./boneage-training-dataset/boneage-training-dataset/15601.png
# ./boneage-training-dataset/boneage-training-dataset/15602.png
# 1/1 [==============================] - 0s 0s/step
# 15602
# ./boneage-training-dataset/boneage-training-dataset/15603.png
# 1/1 [==============================] - 0s 963us/step
# 15603
# ./boneage-training-dataset/boneage-training-dataset/15604.png
# 1/1 [==============================] - 0s 1ms/step
# 15604
# ./boneage-training-dataset/boneage-training-dataset/15605.png
# 1/1 [==============================] - 0s 1ms/step
# 15605
# ./boneage-training-dataset/boneage-training-dataset/15606.png
# 1/1 [==============================] - 0s 1ms/step
# 15606
# ./boneage-training-dataset/boneage-training-dataset/15607.png
# ./boneage-training-dataset/boneage-training-dataset/15608.png
# 1/1 [==============================] - 0s 964us/step
# 15608
# ./boneage-training-dataset/boneage-training-dataset/15609.png
# 1/1 [==============================] - 0s 0s/step
# 15609
# ./boneage-training-dataset/boneage-training-dataset/15610.png
# 1/1 [==============================] - 0s 960us/step
# 15610
# [141.61964, 130.41374, 132.55858, 137.50581, 133.353, 116.05533, 140.25409, 124.78759, 129.5791, 126.3178, 124.672615, 175.79095, 97.139336, 136.25134, 153.47719, 125.34226, 148.71104, 139.50882, 146.6951, 124.99893, 146.34258, 118.881516, 119.97014, 119.62255, 148.88898, 122.91887, 141.50104, 136.96204, 134.52762, 153.25827, 135.54349, 137.51218, 136.99, 125.64621, 115.85824, 132.98535, 162.08424, 132.29109, 138.55273, 139.3918, 128.21442, 138.30838, 146.29088, 127.22568, 130.75114, 114.69796, 138.68576, 114.3446, 126.062386, 136.54381, 122.03023, 132.4094, 125.01772, 94.89595, 143.43164, 151.61176, 116.454735, 137.97255, 153.75073, 115.48484, 117.10842, 144.6217, 111.89224, 144.1142, 115.40196, 140.49988, 146.5936, 134.60007, 142.79146, 120.25665, 164.96854, 140.31935, 127.36039, 129.73795, 141.94873, 133.72382, 130.05037, 116.13523, 133.88269, 129.78316, 117.80724, 159.97458, 128.38272, 132.41638, 105.95116, 115.69994, 116.61681, 100.80604, 149.35306, 146.95502, 158.31682, 122.70091, 114.84107, 136.551, 119.22645, 126.58982, 120.333206, 127.36994, 129.36415, 106.87574, 127.21659, 124.0935, 98.95301, 132.71086, 106.54071, 123.89881, 128.74266, 134.01765, 124.84109, 121.84494, 128.57297, 112.69099, 129.38734, 122.13497, 99.51806, 114.68786, 141.72406, 146.2744, 124.866486, 123.26772, 100.91264, 148.48964, 123.25973, 154.8484, 150.81622, 116.97033, 103.79273, 126.115135, 126.15213, 146.38988, 127.64295, 112.29135, 142.65097, 122.3884, 148.37828, 119.287415, 137.11087, 136.92606, 120.78318, 123.63014, 156.00403, 148.29851, 106.25321, 134.73796, 129.05017, 126.3104, 124.88269
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0, color="blue")
plt.show()

# %%
diferences=[]
for i in range(len(test_list)):
    diferences.append(test_list[i]-res[i])
cuadrados=[]
for i in((diferences)):
    cuadrados.append(i*i)
print("Error cuadrado medio: "+str(sum(cuadrados)/len(cuadrados)))
error_cuadrado_medio=sum(cuadrados)/len(cuadrados)
absolutos=[]
for i in((diferences)):
    if(i<0):
        absolutos.append(i*-1)
    else:
        absolutos.append(i)
print("Error medio absoluto: "+str(sum(absolutos)/len(absolutos)))
error_medio_absoluto=sum(absolutos)/len(absolutos)
# Out:
# Error cuadrado medio: 1154.5854026374718
# Error medio absoluto: 27.34918539780837

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import os
import datetime
import math
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications.xception import preprocess_input
from keras.metrics import mean_absolute_error
from tensorflow.keras.layers import GlobalMaxPooling2D, Dense,Flatten
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.xception import Xception
import time
import random
from sklearn.metrics import mean_absolute_error, mean_squared_error, precision_recall_fscore_support
import csv

# %%
imgSize = 256
media = 127.3207517246848
desviacionS = 41.182021399396326

ba = float(1)
male = True
path = './'

# %%
def mae(xP, yP):
    return mean_absolute_error((desviacionS * xP + media), (desviacionS * yP + media))

    #Modelo
modelo1 = Xception(input_shape = (imgSize, imgSize, 3), include_top = False, weights = 'imagenet')
modelo1.trainable = True

modelo2 = Sequential()
modelo2.add(modelo1)
modelo2.add(GlobalMaxPooling2D())
modelo2.add(Flatten())
modelo2.add(Dense(10, activation = 'relu'))
modelo2.add(Dense(1, activation = 'linear'))
modelo2.compile(loss = 'mse', optimizer = 'adam', metrics = [mae])

modelo2.load_weights('modelo.h5')

# %%
def Prediciendo(nombre):

    df = pd.DataFrame(columns=['id', 'boneage', 'male'])
    df.loc[len(df.index)] = [nombre] + [float(ba)] + [male]
    df['val_z'] = (df['boneage'] - media) / desviacionS
    df['gender'] = df['male'].apply(lambda x: 'male' if x else 'female')

    validationDataGenerator = ImageDataGenerator(preprocessing_function = preprocess_input)


    testX, testY = next(validationDataGenerator.flow_from_dataframe(dataframe = df, directory = path, x_col = 'id', y_col = 'val_z', target_size = (imgSize, imgSize), batch_size = 2523, class_mode = 'raw'))

    def mae(xP, yP):
        return mean_absolute_error((desviacionS * xP + media), (desviacionS * yP + media))

    start_time = time.time()

    prediccion = media + desviacionS * (modelo2.predict(testX, batch_size = 32, verbose = True))

    return prediccion[0][0]

# %%
print(Prediciendo("12537.png"))
# Out:
# Found 1 validated image filenames.
# 1/1 [==============================] - 0s 996us/step
# 156.57568

# %%
import base64
app = dash.Dash(__name__)
app.layout = html.Div([

    html.H1("Boneage", style={'text-align': 'left'}),

    html.Div(id='Sequential',style=({'background-color': '#c7fff8'}), children=[
        html.H2("Secuencial"),
        html.Div(id='Sequential_testing',children=[
            dcc.Upload(
                id='upload-data',
                children=html.Div([
                    'Drag and Drop or Click to ',
                    html.A('Select File')
                ]),
                style={
                    'width': '20%',
                    'height': '60px',
                    'lineHeight': '60px',
                    'borderWidth': '1px',
                    'borderStyle': 'dashed',
                    'borderRadius': '5px',
                    'textAlign': 'center',
                    'margin': '10px'
                },
                # Allow multiple files to be uploaded
                multiple=False
            ),
            html.Div(id='output-data-upload'),
        ]),
        html.Div(id='Sequential_efectiveness',children=[
            dcc.Checklist(id='seq_check',
                options=[
                    {'label': 'Visualizar info del modelo', 'value': '1'}
                ]
            ),
            html.Div(id='Seq_data')
        ])
    ]),
    html.Div(id='Xception',style=({'background-color': '#fff5ad'}), children=[
        html.H2("Xception"),
        html.Div(id='Xception_testing',children=[
            html.Div(dcc.Input(id='input-box', type='text')),
            html.Button('Submit', id='button'),
            html.Div(id='output-container-button',
                     children='Enter a value and press submit')
        ]),
        html.Div(id='Xception_efectiveness',children=[
            dcc.Checklist(id='Xception_check',
                options=[
                    {'label': 'Visualizar info del modelo', 'value': '1'}
                ]
            ),
            html.Div(id='Xception_data')
        ])
    ])
    
])




def getPlot():
    df=pd.DataFrame({
        'Boneage': test_list,
        'Prediction': res
    })
    fig = px.scatter(data_frame =df,x='Boneage',y='Prediction')
    return fig
def evaluate_image(data):
    from PIL import Image
    from io import BytesIO
    content_type, content_string = data.split(',')

    im = Image.open(BytesIO(base64.b64decode(content_string))).resize((128,128)).convert('RGB')
    input_arr = keras.preprocessing.image.img_to_array(im)
    input_arr = np.array([input_arr])  # Convert single image to a batch.
    input_arr=input_arr/256
    predictions = load_15_age_model.predict(input_arr,  verbose = True)[0][0]
    return predictions
@app.callback(Output('Seq_data', 'children'),
    [Input('seq_check', 'value')])
def show_seq(values):
    if (len(values)>0):
        children=[
            html.P(["Error medio absoluto: "+str(error_medio_absoluto)]),
            html.P(["Error cuadrado medio: "+str(error_cuadrado_medio)]),
            dcc.Graph(figure=getPlot())
        ]
        return children
@app.callback(Output('Xception_data', 'children'),
    [Input('Xception_check', 'value')])
def show_Xcep(values):
    if (len(values)>0):
        encoded_image = base64.b64encode(open("./modeloXceptionScatter.jpeg", 'rb').read())
        children=[
            html.P(["Error medio absoluto: 8.534"]),
            html.P(["Error cuadrado medio: 127.967"]),
            html.Img(src='data:image/png;base64,'+str(encoded_image.decode()),style={'height':'30%', 'width':'30%'})
        ]
        return children
@app.callback(
    dash.dependencies.Output('output-container-button', 'children'),
    [dash.dependencies.Input('button', 'n_clicks')],
    [dash.dependencies.State('input-box', 'value')])
def update_Xception(n_clicks, value):
    encoded_image = base64.b64encode(open("./"+value, 'rb').read())
    return [
        html.P(["Prediccion: ",(Prediciendo(value))]),
        html.Img(src='data:image/png;base64,'+str(encoded_image.decode()),style={'height':'10%', 'width':'10%'})
           ]    
@app.callback(Output('output-data-upload', 'children'),
    [Input('upload-data', 'contents')],
    [State('upload-data', 'filename'),
    State('upload-data', 'last_modified')])
def update_Sequential(list_of_contents, list_of_names, list_of_dates):
    if list_of_contents is not None:
        predicted=evaluate_image(list_of_contents)
        children = [
            html.P(["Predicted boneage: ",predicted]),
            html.Img(src=list_of_contents,style={'height':'10%', 'width':'10%'})
        ]
        del list_of_contents, list_of_names, list_of_dates
        return children
if __name__ == '__main__':
    app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# Found 1 validated image filenames.
# 1/1 [==============================] - 0s 3ms/step
